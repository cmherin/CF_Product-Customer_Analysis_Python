# %% [markdown]
# 4.8 Task work

# %% [markdown]
# :: Sections correlate to task question numbers. Questions are headers for each section.

# %% [markdown]
# 1. Create a new notebook for this task. Be sure to import the relevant libraries, along with your ords_prods_merge dataframe, which should include your newly derived columns from the previous Exercise.

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# Create Path

path = r'/Users/chrisherin/Documents/01_Jupyter/11-2021 Instacart Basket Analysis'

# %%
# Import data

df = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merged.pkl'))

# %%
# Check

df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both
#
#                               product_name  aisle_id  department_id  prices  \
# 0                                     Soda      77.0            7.0     9.0
# 1  Organic Unsweetened Vanilla Almond Milk      91.0           16.0    12.5
# 2                      Original Beef Jerky      23.0           19.0     4.4
# 3               Aged White Cheddar Popcorn      23.0           19.0     4.7
# 4         XL Pick-A-Size Paper Towel Rolls      54.0           17.0     1.0
#
#      price_range_loc     busiest_day       busy_days busiest_period_of_day
# 0  Mid-range product  regularly busy  regularly busy        Average orders
# 1  Mid-range product  regularly busy  regularly busy        Average orders
# 2  Low-range product  regularly busy  regularly busy        Average orders
# 3  Low-range product  regularly busy  regularly busy        Average orders
# 4  Low-range product  regularly busy  regularly busy        Average orders

# %%
# Check

df.shape
# Out:
# (32435059, 18)

# %% [markdown]
# 2. In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
# Group by 'product_name' 

df.groupby('product_name')

# %%
# Aggregate 

df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1.0              15.457838
# 2.0              17.277920
# 3.0              17.170395
# 4.0              17.811403
# 5.0              15.215751
# 6.0              16.439806
# 7.0              17.225802
# 8.0              15.340650
# 9.0              15.895474
# 10.0             20.197148
# 11.0             16.170638
# 12.0             15.887671
# 13.0             16.583536
# 14.0             16.773669
# 15.0             16.165037
# 16.0             17.665606
# 17.0             15.694469
# 18.0             19.310397
# 19.0             17.177343
# 20.0             16.473447
# 21.0             22.902379

# %% [markdown]
# 3. Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code.

# %% [markdown]
# :: Running the groupby and agg syntax on the entire df returns higher means for each department than it does for the subset, but not by much. This is expected as the subset was quite smaller than the whole.

# %% [markdown]
# 4. Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %%
# Create new column 'max_order'

df['max_order'] = df.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both
#
#                               product_name  aisle_id  department_id  prices  \
# 0                                     Soda      77.0            7.0     9.0
# 1  Organic Unsweetened Vanilla Almond Milk      91.0           16.0    12.5
# 2                      Original Beef Jerky      23.0           19.0     4.4
# 3               Aged White Cheddar Popcorn      23.0           19.0     4.7
# 4         XL Pick-A-Size Paper Towel Rolls      54.0           17.0     1.0
#
#      price_range_loc     busiest_day       busy_days busiest_period_of_day  \
# 0  Mid-range product  regularly busy  regularly busy        Average orders
# 1  Mid-range product  regularly busy  regularly busy        Average orders
# 2  Low-range product  regularly busy  regularly busy        Average orders
# 3  Low-range product  regularly busy  regularly busy        Average orders
# 4  Low-range product  regularly busy  regularly busy        Average orders
#
#    max_order
# 0         10
# 1         10
# 2         10
# 3         10
# 4         10

# %% [markdown]
# Change the amount of rows printed. Added for future ref.

# %%
# Show all rows printed in .head()

pd.options.display.max_rows = None

# %%
df.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 3    2539329        1             1                   2                  8
# 4    2539329        1             1                   2                  8
# 5    2398795        1             2                   3                  7
# 6    2398795        1             2                   3                  7
# 7    2398795        1             2                   3                  7
# 8    2398795        1             2                   3                  7
# 9    2398795        1             2                   3                  7
# 10   2398795        1             2                   3                  7
# 11    473747        1             3                   3                 12
# 12    473747        1             3                   3                 12
# 13    473747        1             3                   3                 12
# 14    473747        1             3                   3                 12
# 15    473747        1             3                   3                 12
# 16   2254736        1             4                   4                  7
# 17   2254736        1             4                   4                  7
# 18   2254736        1             4                   4                  7
# 19   2254736        1             4                   4                  7
# 20   2254736        1             4                   4                  7
# 21    431534        1             5                   4                 15
# 22    431534        1             5                   4                 15
# 23    431534        1             5                   4                 15
# 24    431534        1             5                   4                 15
# 25    431534        1             5                   4                 15
# 26    431534        1             5                   4                 15
# 27    431534        1             5                   4                 15
# 28    431534        1             5                   4                 15
# 29   3367565        1             6                   2                  7
# 30   3367565        1             6                   2                  7
# 31   3367565        1             6                   2                  7
# 32   3367565        1             6                   2                  7
# 33    550135        1             7                   1                  9
# 34    550135        1             7                   1                  9
# 35    550135        1             7                   1                  9
# 36    550135        1             7                   1                  9
# 37    550135        1             7                   1                  9
# 38   3108588        1             8                   1                 14
# 39   3108588        1             8                   1                 14
# 40   3108588        1             8                   1                 14
# 41   3108588        1             8                   1                 14
# 42   3108588        1             8                   1                 14
# 43   3108588        1             8                   1                 14
# 44   2295261        1             9                   1                 16
# 45   2295261        1             9                   1                 16
# 46   2295261        1             9                   1                 16
# 47   2295261        1             9                   1                 16
# 48   2295261        1             9                   1                 16
# 49   2295261        1             9                   1                 16
# 50   2550362        1            10                   4                  8
# 51   2550362        1            10                   4                  8
# 52   2550362        1            10                   4                  8
# 53   2550362        1            10                   4                  8
# 54   2550362        1            10                   4                  8
# 55   2550362        1            10                   4                  8
# 56   2550362        1            10                   4                  8
# 57   2550362        1            10                   4                  8
# 58   2550362        1            10                   4                  8
# 59   2168274        2             1                   2                 11
# 60   2168274        2             1                   2                 11
# 61   2168274        2             1                   2                 11
# 62   2168274        2             1                   2                 11
# 63   2168274        2             1                   2                 11
# 64   2168274        2             1                   2                 11
# 65   2168274        2             1                   2                 11
# 66   2168274        2             1                   2                 11
# 67   2168274        2             1                   2                 11
# 68   2168274        2             1                   2                 11
# 69   2168274        2             1                   2                 11
# 70   2168274        2             1                   2                 11
# 71   2168274        2             1                   2                 11
# 72   1501582        2             2                   5                 10
# 73   1501582        2             2                   5                 10
# 74   1501582        2             2                   5                 10
# 75   1501582        2             2                   5                 10
# 76   1501582        2             2                   5                 10
# 77   1501582        2             2                   5                 10
# 78   1901567        2             3                   1                 10
# 79   1901567        2             3                   1                 10
# 80   1901567        2             3                   1                 10
# 81   1901567        2             3                   1                 10
# 82   1901567        2             3                   1                 10
# 83    738281        2             4                   2                 10
# 84    738281        2             4                   2                 10
# 85    738281        2             4                   2                 10
# 86    738281        2             4                   2                 10
# 87    738281        2             4                   2                 10
# 88    738281        2             4                   2                 10
# 89    738281        2             4                   2                 10
# 90    738281        2             4                   2                 10
# 91    738281        2             4                   2                 10
# 92    738281        2             4                   2                 10
# 93    738281        2             4                   2                 10
# 94    738281        2             4                   2                 10
# 95    738281        2             4                   2                 10
# 96   1673511        2             5                   3                 11
# 97   1673511        2             5                   3                 11
# 98   1673511        2             5                   3                 11
# 99   1673511        2             5                   3                 11
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                      NaN         196                  1          0   both
# 1                      NaN       14084                  2          0   both
# 2                      NaN       12427                  3          0   both
# 3                      NaN       26088                  4          0   both
# 4                      NaN       26405                  5          0   both
# 5                     15.0         196                  1          1   both
# 6                     15.0       10258                  2          0   both
# 7                     15.0       12427                  3          1   both
# 8                     15.0       13176                  4          0   both
# 9                     15.0       26088                  5          1   both
# 10                    15.0       13032                  6          0   both
# 11                    21.0         196                  1          1   both
# 12                    21.0       12427                  2          1   both
# 13                    21.0       10258                  3          1   both
# 14                    21.0       25133                  4          0   both
# 15                    21.0       30450                  5          0   both
# 16                    29.0         196                  1          1   both
# 17                    29.0       12427                  2          1   both
# 18                    29.0       10258                  3          1   both
# 19                    29.0       25133                  4          1   both
# 20                    29.0       26405                  5          1   both
# 21                    28.0         196                  1          1   both
# 22                    28.0       12427                  2          1   both
# 23                    28.0       10258                  3          1   both
# 24                    28.0       25133                  4          1   both
# 25                    28.0       10326                  5          0   both
# 26                    28.0       17122                  6          0   both
# 27                    28.0       41787                  7          0   both
# 28                    28.0       13176                  8          1   both
# 29                    19.0         196                  1          1   both
# 30                    19.0       12427                  2          1   both
# 31                    19.0       10258                  3          1   both
# 32                    19.0       25133                  4          1   both
# 33                    20.0         196                  1          1   both
# 34                    20.0       10258                  2          1   both
# 35                    20.0       12427                  3          1   both
# 36                    20.0       25133                  4          1   both
# 37                    20.0       13032                  5          1   both
# 38                    14.0       12427                  1          1   both
# 39                    14.0         196                  2          1   both
# 40                    14.0       10258                  3          1   both
# 41                    14.0       25133                  4          1   both
# 42                    14.0       46149                  5          0   both
# 43                    14.0       49235                  6          0   both
# 44                     0.0       49235                  1          1   both
# 45                     0.0       46149                  2          1   both
# 46                     0.0       25133                  3          1   both
# 47                     0.0         196                  4          1   both
# 48                     0.0       10258                  5          1   both
# 49                     0.0       12427                  6          1   both
# 50                    30.0         196                  1          1   both
# 51                    30.0       46149                  2          1   both
# 52                    30.0       39657                  3          0   both
# 53                    30.0       38928                  4          0   both
# 54                    30.0       25133                  5          1   both
# 55                    30.0       10258                  6          1   both
# 56                    30.0       35951                  7          0   both
# 57                    30.0       13032                  8          1   both
# 58                    30.0       12427                  9          1   both
# 59                     NaN       32792                  1          0   both
# 60                     NaN       47766                  2          0   both
# 61                     NaN       20574                  3          0   both
# 62                     NaN       12000                  4          0   both
# 63                     NaN       48110                  5          0   both
# 64                     NaN       22474                  6          0   both
# 65                     NaN       16589                  7          0   both
# 66                     NaN       35917                  8          0   both
# 67                     NaN       27344                  9          0   both
# 68                     NaN       30489                 10          0   both
# 69                     NaN       27966                 11          0   both
# 70                     NaN       13176                 12          0   both
# 71                     NaN       45066                 13          0   both
# 72                    10.0       16797                  1          0   both
# 73                    10.0       47526                  2          0   both
# 74                    10.0        8479                  3          0   both
# 75                    10.0       47766                  4          1   both
# 76                    10.0       19051                  5          0   both
# 77                    10.0        8138                  6          0   both
# 78                     3.0       47766                  1          1   both
# 79                     3.0       32792                  2          1   both
# 80                     3.0       20574                  3          1   both
# 81                     3.0        7781                  4          0   both
# 82                     3.0       28874                  5          0   both
# 83                     8.0       49451                  1          0   both
# 84                     8.0       32792                  2          1   both
# 85                     8.0       32139                  3          0   both
# 86                     8.0       34688                  4          0   both
# 87                     8.0       36735                  5          0   both
# 88                     8.0       37646                  6          0   both
# 89                     8.0       22829                  7          0   both
# 90                     8.0       24852                  8          0   both
# 91                     8.0       47209                  9          0   both
# 92                     8.0       33276                 10          0   both
# 93                     8.0       45613                 11          0   both
# 94                     8.0        9681                 12          0   both
# 95                     8.0       21150                 13          0   both
# 96                     8.0       47144                  1          0   both
# 97                     8.0        5322                  2          0   both
# 98                     8.0       17224                  3          0   both
# 99                     8.0       38656                  4          0   both
#
#                                          product_name  aisle_id  \
# 0                                                Soda      77.0
# 1             Organic Unsweetened Vanilla Almond Milk      91.0
# 2                                 Original Beef Jerky      23.0
# 3                          Aged White Cheddar Popcorn      23.0
# 4                    XL Pick-A-Size Paper Towel Rolls      54.0
# 5                                                Soda      77.0
# 6                                          Pistachios     117.0
# 7                                 Original Beef Jerky      23.0
# 8                              Bag of Organic Bananas      24.0
# 9                          Aged White Cheddar Popcorn      23.0
# 10                              Cinnamon Toast Crunch     121.0
# 11                                               Soda      77.0
# 12                                Original Beef Jerky      23.0
# 13                                         Pistachios     117.0
# 14                              Organic String Cheese      21.0
# 15                               Creamy Almond Butter      88.0
# 16                                               Soda      77.0
# 17                                Original Beef Jerky      23.0
# 18                                         Pistachios     117.0
# 19                              Organic String Cheese      21.0
# 20                   XL Pick-A-Size Paper Towel Rolls      54.0
# 21                                               Soda      77.0
# 22                                Original Beef Jerky      23.0
# 23                                         Pistachios     117.0
# 24                              Organic String Cheese      21.0
# 25                                Organic Fuji Apples      24.0
# 26                                  Honeycrisp Apples      24.0
# 27                                     Bartlett Pears      24.0
# 28                             Bag of Organic Bananas      24.0
# 29                                               Soda      77.0
# 30                                Original Beef Jerky      23.0
# 31                                         Pistachios     117.0
# 32                              Organic String Cheese      21.0
# 33                                               Soda      77.0
# 34                                         Pistachios     117.0
# 35                                Original Beef Jerky      23.0
# 36                              Organic String Cheese      21.0
# 37                              Cinnamon Toast Crunch     121.0
# 38                                Original Beef Jerky      23.0
# 39                                               Soda      77.0
# 40                                         Pistachios     117.0
# 41                              Organic String Cheese      21.0
# 42                                  Zero Calorie Cola      77.0
# 43                                Organic Half & Half      53.0
# 44                                Organic Half & Half      53.0
# 45                                  Zero Calorie Cola      77.0
# 46                              Organic String Cheese      21.0
# 47                                               Soda      77.0
# 48                                         Pistachios     117.0
# 49                                Original Beef Jerky      23.0
# 50                                               Soda      77.0
# 51                                  Zero Calorie Cola      77.0
# 52                             Milk Chocolate Almonds      45.0
# 53                           0% Greek Strained Yogurt     120.0
# 54                              Organic String Cheese      21.0
# 55                                         Pistachios     117.0
# 56                    Organic Unsweetened Almond Milk      91.0
# 57                              Cinnamon Toast Crunch     121.0
# 58                                Original Beef Jerky      23.0
# 59                     Chipotle Beef & Pork Realstick      23.0
# 60                                    Organic Avocado      24.0
# 61                                     Roasted Turkey      96.0
# 62           Baked Organic Sea Salt Crunchy Pea Snack      72.0
# 63            Thin Stackers Brown Rice Lightly Salted      78.0
# 64                     Cheddar Bunnies Snack Crackers      78.0
# 65                                     Plantain Chips     107.0
# 66                   Organic Just Concord Grape Juice      98.0
# 67                               Uncured Genoa Salami      96.0
# 68                                    Original Hummus      67.0
# 69                                Organic Raspberries     123.0
# 70                             Bag of Organic Bananas      24.0
# 71                                   Honeycrisp Apple      24.0
# 72                                       Strawberries      24.0
# 73                                    Goat Cheese Log      21.0
# 74              Original Black Box Tablewater Cracker      78.0
# 75                                    Organic Avocado      24.0
# 76               Pita Chips, Simply Naked, Party Size     107.0
# 77                                 Traditional Hummus      67.0
# 78                                    Organic Avocado      24.0
# 79                     Chipotle Beef & Pork Realstick      23.0
# 80                                     Roasted Turkey      96.0
# 81  Organic Sticks Low Moisture Part Skim Mozzarel...      21.0
# 82                                 Carrot Ginger Soup       1.0
# 83                              Artichoke Spinach Dip      67.0
# 84                     Chipotle Beef & Pork Realstick      23.0
# 85                            Hommus Classic Original      67.0
# 86  Good Belly Probiotics Juice Drink Blueberry Ac...      31.0
# 87              Organic Roasted Sliced Chicken Breast      96.0
# 88                                Organic Gala Apples      24.0
# 89          Multigrain Flax Seeded Flatbread Crackers      78.0
# 90                                             Banana      24.0
# 91                               Organic Hass Avocado      24.0
# 92                              Kalamata Olive Spread      67.0
# 93                                           Pad Thai      38.0
# 94  Chicken Tikka Masala with Cumin Infused Basmat...      38.0
# 95                            Fire Grilled Steak Bowl      38.0
# 96     Unsweetened Original Almond Breeze Almond Milk      91.0
# 97  Gluten Free Dark Chocolate Chunk Chewy with a ...       3.0
# 98                   Oats & Honey Gluten Free Granola       3.0
# 99  Gluten Free Peanut Butter Dark Chocolate Chewy...       3.0
#
#     department_id  prices    price_range_loc     busiest_day       busy_days  \
# 0             7.0     9.0  Mid-range product  regularly busy  regularly busy
# 1            16.0    12.5  Mid-range product  regularly busy  regularly busy
# 2            19.0     4.4  Low-range product  regularly busy  regularly busy
# 3            19.0     4.7  Low-range product  regularly busy  regularly busy
# 4            17.0     1.0  Low-range product  regularly busy  regularly busy
# 5             7.0     9.0  Mid-range product  regularly busy  regularly busy
# 6            19.0     3.0  Low-range product  regularly busy  regularly busy
# 7            19.0     4.4  Low-range product  regularly busy  regularly busy
# 8             4.0    10.3  Mid-range product  regularly busy  regularly busy
# 9            19.0     4.7  Low-range product  regularly busy  regularly busy
# 10           14.0     4.0  Low-range product  regularly busy  regularly busy
# 11            7.0     9.0  Mid-range product  regularly busy  regularly busy
# 12           19.0     4.4  Low-range product  regularly busy  regularly busy
# 13           19.0     3.0  Low-range product  regularly busy  regularly busy
# 14           16.0     8.6  Mid-range product  regularly busy  regularly busy
# 15           13.0     3.2  Low-range product  regularly busy  regularly busy
# 16            7.0     9.0  Mid-range product      least busy    slowest days
# 17           19.0     4.4  Low-range product      least busy    slowest days
# 18           19.0     3.0  Low-range product      least busy    slowest days
# 19           16.0     8.6  Mid-range product      least busy    slowest days
# 20           17.0     1.0  Low-range product      least busy    slowest days
# 21            7.0     9.0  Mid-range product      least busy    slowest days
# 22           19.0     4.4  Low-range product      least busy    slowest days
# 23           19.0     3.0  Low-range product      least busy    slowest days
# 24           16.0     8.6  Mid-range product      least busy    slowest days
# 25            4.0     2.7  Low-range product      least busy    slowest days
# 26            4.0    14.0  Mid-range product      least busy    slowest days
# 27            4.0     5.0  Low-range product      least busy    slowest days
# 28            4.0    10.3  Mid-range product      least busy    slowest days
# 29            7.0     9.0  Mid-range product  regularly busy  regularly busy
# 30           19.0     4.4  Low-range product  regularly busy  regularly busy
# 31           19.0     3.0  Low-range product  regularly busy  regularly busy
# 32           16.0     8.6  Mid-range product  regularly busy  regularly busy
# 33            7.0     9.0  Mid-range product  regularly busy    busiest days
# 34           19.0     3.0  Low-range product  regularly busy    busiest days
# 35           19.0     4.4  Low-range product  regularly busy    busiest days
# 36           16.0     8.6  Mid-range product  regularly busy    busiest days
# 37           14.0     4.0  Low-range product  regularly busy    busiest days
# 38           19.0     4.4  Low-range product  regularly busy    busiest days
# 39            7.0     9.0  Mid-range product  regularly busy    busiest days
# 40           19.0     3.0  Low-range product  regularly busy    busiest days
# 41           16.0     8.6  Mid-range product  regularly busy    busiest days
# 42            7.0    13.4  Mid-range product  regularly busy    busiest days
# 43           16.0     1.8  Low-range product  regularly busy    busiest days
# 44           16.0     1.8  Low-range product  regularly busy    busiest days
# 45            7.0    13.4  Mid-range product  regularly busy    busiest days
# 46           16.0     8.6  Mid-range product  regularly busy    busiest days
# 47            7.0     9.0  Mid-range product  regularly busy    busiest days
# 48           19.0     3.0  Low-range product  regularly busy    busiest days
# 49           19.0     4.4  Low-range product  regularly busy    busiest days
# 50            7.0     9.0  Mid-range product      least busy    slowest days
# 51            7.0    13.4  Mid-range product      least busy    slowest days
# 52           19.0     6.8  Mid-range product      least busy    slowest days
# 53           16.0    12.6  Mid-range product      least busy    slowest days
# 54           16.0     8.6  Mid-range product      least busy    slowest days
# 55           19.0     3.0  Low-range product      least busy    slowest days
# 56           16.0     1.3  Low-range product      least busy    slowest days
# 57           14.0     4.0  Low-range product      least busy    slowest days
# 58           19.0     4.4  Low-range product      least busy    slowest days
# 59           19.0     5.2  Mid-range product  regularly busy  regularly busy
# 60            4.0     6.3  Mid-range product  regularly busy  regularly busy
# 61           20.0     2.3  Low-range product  regularly busy  regularly busy
# 62           13.0    10.9  Mid-range product  regularly busy  regularly busy
# 63           19.0     2.7  Low-range product  regularly busy  regularly busy
# 64           19.0     4.1  Low-range product  regularly busy  regularly busy
# 65           19.0     5.0  Low-range product  regularly busy  regularly busy
# 66            7.0     9.4  Mid-range product  regularly busy  regularly busy
# 67           20.0    14.8  Mid-range product  regularly busy  regularly busy
# 68           20.0     7.5  Mid-range product  regularly busy  regularly busy
# 69            4.0     4.4  Low-range product  regularly busy  regularly busy
# 70            4.0    10.3  Mid-range product  regularly busy  regularly busy
# 71            4.0     2.5  Low-range product  regularly busy  regularly busy
# 72            4.0     1.3  Low-range product  regularly busy  regularly busy
# 73           16.0     2.0  Low-range product  regularly busy  regularly busy
# 74           19.0     3.5  Low-range product  regularly busy  regularly busy
# 75            4.0     6.3  Mid-range product  regularly busy  regularly busy
# 76           19.0     3.9  Low-range product  regularly busy  regularly busy
# 77           20.0     2.0  Low-range product  regularly busy  regularly busy
# 78            4.0     6.3  Mid-range product  regularly busy    busiest days
# 79           19.0     5.2  Mid-range product  regularly busy    busiest days
# 80           20.0     2.3  Low-range product  regularly busy    busiest days
# 81           16.0     6.6  Mid-range product  regularly busy    busiest days
# 82           20.0     6.2  Mid-range product  regularly busy    busiest days
# 83           20.0     7.1  Mid-range product  regularly busy  regularly busy
# 84           19.0     5.2  Mid-range product  regularly busy  regularly busy
# 85           20.0     7.5  Mid-range product  regularly busy  regularly busy
# 86            7.0     5.8  Mid-range product  regularly busy  regularly busy
# 87           20.0     8.9  Mid-range product  regularly busy  regularly busy
# 88            4.0     9.1  Mid-range product  regularly busy  regularly busy
# 89           19.0     5.5  Mid-range product  regularly busy  regularly busy
# 90            4.0    12.3  Mid-range product  regularly busy  regularly busy
# 91            4.0     4.0  Low-range product  regularly busy  regularly busy
# 92           20.0    10.8  Mid-range product  regularly busy  regularly busy
# 93            1.0    12.6  Mid-range product  regularly busy  regularly busy
# 94            1.0     2.0  Low-range product  regularly busy  regularly busy
# 95            1.0     5.9  Mid-range product  regularly busy  regularly busy
# 96           16.0    14.0  Mid-range product  regularly busy  regularly busy
# 97           19.0     2.9  Low-range product  regularly busy  regularly busy
# 98           19.0     1.6  Low-range product  regularly busy  regularly busy
# 99           19.0     3.4  Low-range product  regularly busy  regularly busy
#
#    busiest_period_of_day  max_order
# 0         Average orders         10
# 1         Average orders         10
# 2         Average orders         10
# 3         Average orders         10
# 4         Average orders         10
# 5         Average orders         10
# 6         Average orders         10
# 7         Average orders         10
# 8         Average orders         10
# 9         Average orders         10
# 10        Average orders         10
# 11           Most orders         10
# 12           Most orders         10
# 13           Most orders         10
# 14           Most orders         10
# 15           Most orders         10
# 16        Average orders         10
# 17        Average orders         10
# 18        Average orders         10
# 19        Average orders         10
# 20        Average orders         10
# 21           Most orders         10
# 22           Most orders         10
# 23           Most orders         10
# 24           Most orders         10
# 25           Most orders         10
# 26           Most orders         10
# 27           Most orders         10
# 28           Most orders         10
# 29        Average orders         10
# 30        Average orders         10
# 31        Average orders         10
# 32        Average orders         10
# 33        Average orders         10
# 34        Average orders         10
# 35        Average orders         10
# 36        Average orders         10
# 37        Average orders         10
# 38           Most orders         10
# 39           Most orders         10
# 40           Most orders         10
# 41           Most orders         10
# 42           Most orders         10
# 43           Most orders         10
# 44           Most orders         10
# 45           Most orders         10
# 46           Most orders         10
# 47           Most orders         10
# 48           Most orders         10
# 49           Most orders         10
# 50        Average orders         10
# 51        Average orders         10
# 52        Average orders         10
# 53        Average orders         10
# 54        Average orders         10
# 55        Average orders         10
# 56        Average orders         10
# 57        Average orders         10
# 58        Average orders         10
# 59           Most orders         14
# 60           Most orders         14
# 61           Most orders         14
# 62           Most orders         14
# 63           Most orders         14
# 64           Most orders         14
# 65           Most orders         14
# 66           Most orders         14
# 67           Most orders         14
# 68           Most orders         14
# 69           Most orders         14
# 70           Most orders         14
# 71           Most orders         14
# 72           Most orders         14
# 73           Most orders         14
# 74           Most orders         14
# 75           Most orders         14
# 76           Most orders         14
# 77           Most orders         14
# 78           Most orders         14
# 79           Most orders         14
# 80           Most orders         14
# 81           Most orders         14
# 82           Most orders         14
# 83           Most orders         14
# 84           Most orders         14
# 85           Most orders         14
# 86           Most orders         14
# 87           Most orders         14
# 88           Most orders         14
# 89           Most orders         14
# 90           Most orders         14
# 91           Most orders         14
# 92           Most orders         14
# 93           Most orders         14
# 94           Most orders         14
# 95           Most orders         14
# 96           Most orders         14
# 97           Most orders         14
# 98           Most orders         14
# 99           Most orders         14

# %%
# Orders over 40 = 'loyal customer'

df.loc[df['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
# Orders 11 - 39 = 'regular customer'

df.loc[(df['max_order'] <= 40) & (df['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
# Orders 10 or less = 'new customer'

df.loc[df['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Value counts for new loyalty flag

df['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15891507
# Loyal customer      10294027
# New customer         6249525
# Name: loyalty_flag, dtype: int64

# %%
df[['user_id', 'loyalty_flag', 'order_number']].head(100)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# 20        1      New customer             4
# 21        1      New customer             5
# 22        1      New customer             5
# 23        1      New customer             5
# 24        1      New customer             5
# 25        1      New customer             5
# 26        1      New customer             5
# 27        1      New customer             5
# 28        1      New customer             5
# 29        1      New customer             6
# 30        1      New customer             6
# 31        1      New customer             6
# 32        1      New customer             6
# 33        1      New customer             7
# 34        1      New customer             7
# 35        1      New customer             7
# 36        1      New customer             7
# 37        1      New customer             7
# 38        1      New customer             8
# 39        1      New customer             8
# 40        1      New customer             8
# 41        1      New customer             8
# 42        1      New customer             8
# 43        1      New customer             8
# 44        1      New customer             9
# 45        1      New customer             9
# 46        1      New customer             9
# 47        1      New customer             9
# 48        1      New customer             9
# 49        1      New customer             9
# 50        1      New customer            10
# 51        1      New customer            10
# 52        1      New customer            10
# 53        1      New customer            10
# 54        1      New customer            10
# 55        1      New customer            10
# 56        1      New customer            10
# 57        1      New customer            10
# 58        1      New customer            10
# 59        2  Regular customer             1
# 60        2  Regular customer             1
# 61        2  Regular customer             1
# 62        2  Regular customer             1
# 63        2  Regular customer             1
# 64        2  Regular customer             1
# 65        2  Regular customer             1
# 66        2  Regular customer             1
# 67        2  Regular customer             1
# 68        2  Regular customer             1
# 69        2  Regular customer             1
# 70        2  Regular customer             1
# 71        2  Regular customer             1
# 72        2  Regular customer             2
# 73        2  Regular customer             2
# 74        2  Regular customer             2
# 75        2  Regular customer             2
# 76        2  Regular customer             2
# 77        2  Regular customer             2
# 78        2  Regular customer             3
# 79        2  Regular customer             3
# 80        2  Regular customer             3
# 81        2  Regular customer             3
# 82        2  Regular customer             3
# 83        2  Regular customer             4
# 84        2  Regular customer             4
# 85        2  Regular customer             4
# 86        2  Regular customer             4
# 87        2  Regular customer             4
# 88        2  Regular customer             4
# 89        2  Regular customer             4
# 90        2  Regular customer             4
# 91        2  Regular customer             4
# 92        2  Regular customer             4
# 93        2  Regular customer             4
# 94        2  Regular customer             4
# 95        2  Regular customer             4
# 96        2  Regular customer             5
# 97        2  Regular customer             5
# 98        2  Regular customer             5
# 99        2  Regular customer             5

# %% [markdown]
# 5. The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
df.groupby('loyalty_flag').agg({'prices': ['mean', 'median', 'min', 'max']})
# Out:
#                      prices
#                        mean median  min      max
# loyalty_flag
# Loyal customer    10.386336    7.4  1.0  99999.0
# New customer      13.294670    7.4  1.0  99999.0
# Regular customer  12.495717    7.4  1.0  99999.0

# %% [markdown]
# :: It seems that the 'loyal customer' category has a lower average price with 'new customer' having the highest price.

# %% [markdown]
# 6. The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria:

# %% [markdown]
# - If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”

# %% [markdown]
# - If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
# Create new column 'spending'

df['spending'] = df.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# Check

df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both
#
#    ... aisle_id  department_id  prices    price_range_loc     busiest_day  \
# 0  ...     77.0            7.0     9.0  Mid-range product  regularly busy
# 1  ...     91.0           16.0    12.5  Mid-range product  regularly busy
# 2  ...     23.0           19.0     4.4  Low-range product  regularly busy
# 3  ...     23.0           19.0     4.7  Low-range product  regularly busy
# 4  ...     54.0           17.0     1.0  Low-range product  regularly busy
#
#         busy_days busiest_period_of_day max_order  loyalty_flag  spending
# 0  regularly busy        Average orders        10  New customer  6.367797
# 1  regularly busy        Average orders        10  New customer  6.367797
# 2  regularly busy        Average orders        10  New customer  6.367797
# 3  regularly busy        Average orders        10  New customer  6.367797
# 4  regularly busy        Average orders        10  New customer  6.367797
#
# [5 rows x 21 columns]

# %% [markdown]
# :: Create criteria for 'spending' column

# %%
# Mean 'prices' lower than 10 = 'low spender'

df.loc[df['spending'] < 10, 'spending_flag'] = 'Low spender'

# %%
# Mean 'prices' equal or higher than 10 = 'high spender'

df.loc[df['spending'] >= 10, 'spending_flag'] = 'High spender'

# %%
# Spending stats

df['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     31800414
# High spender      634645
# Name: spending_flag, dtype: int64

# %% [markdown]
# 7. In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:

# %% [markdown]
# - If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”

# %% [markdown]
# - If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”

# %% [markdown]
# - If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
# Create new column 'buyer_frequency'

df['frequency'] = df.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# Check

df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both
#
#    ... prices    price_range_loc     busiest_day       busy_days  \
# 0  ...    9.0  Mid-range product  regularly busy  regularly busy
# 1  ...   12.5  Mid-range product  regularly busy  regularly busy
# 2  ...    4.4  Low-range product  regularly busy  regularly busy
# 3  ...    4.7  Low-range product  regularly busy  regularly busy
# 4  ...    1.0  Low-range product  regularly busy  regularly busy
#
#   busiest_period_of_day max_order  loyalty_flag  spending  spending_flag  \
# 0        Average orders        10  New customer  6.367797    Low spender
# 1        Average orders        10  New customer  6.367797    Low spender
# 2        Average orders        10  New customer  6.367797    Low spender
# 3        Average orders        10  New customer  6.367797    Low spender
# 4        Average orders        10  New customer  6.367797    Low spender
#
#   frequency
# 0      20.5
# 1      20.5
# 2      20.5
# 3      20.5
# 4      20.5
#
# [5 rows x 23 columns]

# %% [markdown]
# :: Create criteria for 'frequency' column

# %%
# Median 'days_since_prior_order' higher than 20 = 'non-frequent customer'

df.loc[df['frequency'] > 20, 'freq_flag'] = 'non-frequent customer'

# %%
# Median 'days_since_prior_order' higher than 10 and lower than or equal to 20 = 'regular customer'

df.loc[(df['frequency'] > 10) & (df['frequency'] <= 20), 'freq_flag'] = 'regular customer'

# %%
# Median 'days_since_prior_order' lower than or equal to 10 = 'frequent customer'

df.loc[df['frequency'] <= 10, 'freq_flag'] = 'frequent customer'

# %%
# Frequency stats

df['freq_flag'].value_counts(dropna = False)
# Out:
# frequent customer        21578273
# regular customer          7217066
# non-frequent customer     3639720
# Name: freq_flag, dtype: int64

# %%
# Export df

df.to_pickle(os.path.join(path,'02 Data','Prepared Data','ords_prods_merg48.pkl'))
